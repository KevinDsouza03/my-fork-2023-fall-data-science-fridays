# %%
import pandas as pd

# %%
download_url = (
      "https://raw.githubusercontent.com/fivethirtyeight/"
        "data/master/college-majors/recent-grads.csv"
)

# %%
df = pd.read_csv(download_url)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option("display.max.columns",None)
df.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       1849        270                  1207          37           0.018381
# 1        556        170                   388          85           0.117241
# 2        558        133                   340          16           0.024096
# 3       1069        150                   692          40           0.050125
# 4      23170       5180                 16697        1672           0.061098
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972

# %%
# %matplotlib inline

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7796/2880618261.py in <module>
# ----> 1 df.plot(x="Rank", y=["P25th", "Median", "P75th"]).bar()
#
# ~\.julia\conda\3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1473     def inner(ax, *args, data=None, **kwargs):
#    1474         if data is None:
# -> 1475             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1476
#    1477         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df["Rank"], df["P75th"])

# %%
median_column = df["Median"]

# %%
type(median_column)
# Out:
# pandas.core.series.Series

# %%
median_column.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
top_5 = df.sort_values(by="Median",ascending=False).head()

# %%
top_5
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       1849        270                  1207          37           0.018381
# 1        556        170                   388          85           0.117241
# 2        558        133                   340          16           0.024096
# 3       1069        150                   692          40           0.050125
# 4      23170       5180                 16697        1672           0.061098
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972

# %%
top_5.plot(x="Major",y="Median",kind="bar",rot=7,fontsize=7)
# Out:
# <Axes: xlabel='Major'>

# %%
top_medians = df[df["Median"] > 60000].sort_values("Median")

# %%
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")
# Out:
# <Axes: xlabel='Major'>

# %%
cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()
#grouping by major category and getting total num ppl in each major
small_cat_totals = cat_totals[cat_totals < 100_000]
big_cat_totals = cat_totals[cat_totals > 100_000]

# %%
small_sums = pd.Series([small_cat_totals.sum()], index=["Other"])

# %%
big_cat_totals = big_cat_totals.append(small_sums)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7796/4256570708.py in <module>
# ----> 1 big_cat_totals = big_cat_totals.append(small_sums)
#
# ~\.julia\conda\3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
big_cat_totals.plot(kind="pie", label='')
# Out:
# <Axes: >
